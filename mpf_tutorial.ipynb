# %% [markdown]
# <a href="https://colab.research.google.com/github/hy2632/SystematicTrading/blob/main/mpf_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !pip install mplfinance
import mplfinance as mpf
from pandas_datareader import data
# !pip install yfinance
import yfinance

# %%
daily = data.get_data_yahoo("SPY", "20191101", "20191130")

# %%
daily = daily[daily.columns[[2,0,1,3,4]]]

# %%
daily.shape
daily.tail(3)
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2019-11-26  313.410004  314.279999  313.059998  314.079987  37569000
# 2019-11-27  314.609985  315.480011  314.369995  315.480011  44444600
# 2019-11-29  314.859985  315.130005  314.059998  314.309998  36592700

# %%
mpf.plot(daily)

# %%
mpf.plot(daily, type="candle")

# %%
mpf.plot(daily, type="line")

# %%
intraday = yfinance.download(tickers="SPY", period="5d", interval="30m")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mpf.plot(intraday, type="candle", mav=(7,12)) #, show_nontrading=True)

# %%
df = yfinance.download(tickers="SPY", start="2020-12-31", end=("2021-01-12"), interval="30m")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mpf.plot(df, type="candle", volume=True, mav=(20,40))
